# %%
import pandas as pd
import datetime as dt
data=pd.read_csv('covid_19_india.csv', parse_dates=['Date'], dayfirst=True)
data
# Out:
#      Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0      1 2020-01-30  6:00 PM               Kerala                       1
# 1      2 2020-01-31  6:00 PM               Kerala                       1
# 2      3 2020-02-01  6:00 PM               Kerala                       2
# 3      4 2020-02-02  6:00 PM               Kerala                       3
# 4      5 2020-02-03  6:00 PM               Kerala                       3
# ..   ...        ...      ...                  ...                     ...
# 858  859 2020-04-11  5:00 PM            Telengana                       -
# 859  860 2020-04-11  5:00 PM              Tripura                       -
# 860  861 2020-04-11  5:00 PM          Uttarakhand                       -
# 861  862 2020-04-11  5:00 PM        Uttar Pradesh                       -
# 862  863 2020-04-11  5:00 PM          West Bengal                       -
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       863 non-null    int64
#  1   Date                      863 non-null    datetime64[ns]
#  2   Time                      863 non-null    object
#  3   State/UnionTerritory      863 non-null    object
#  4   ConfirmedIndianNational   863 non-null    object
#  5   ConfirmedForeignNational  863 non-null    object
#  6   Cured                     863 non-null    int64
#  7   Deaths                    863 non-null    int64
#  8   Confirmed                 863 non-null    int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 60.8+ KB

# %%
data=data[['Date','State/UnionTerritory','Cured','Deaths','Confirmed']]
data
# Out:
#           Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0   2020-01-30               Kerala      0       0          1
# 1   2020-01-31               Kerala      0       0          1
# 2   2020-02-01               Kerala      0       0          2
# 3   2020-02-02               Kerala      0       0          3
# 4   2020-02-03               Kerala      0       0          3
# ..         ...                  ...    ...     ...        ...
# 858 2020-04-11            Telengana     43       9        504
# 859 2020-04-11              Tripura      0       0          2
# 860 2020-04-11          Uttarakhand      5       0         35
# 861 2020-04-11        Uttar Pradesh     32       4        433
# 862 2020-04-11          West Bengal     16       5        126
#
# [863 rows x 5 columns]

# %%
data.columns=['Date','State','Cured','Deaths','Confirmed']
data.head()
# Out:
#         Date   State  Cured  Deaths  Confirmed
# 0 2020-01-30  Kerala      0       0          1
# 1 2020-01-31  Kerala      0       0          1
# 2 2020-02-01  Kerala      0       0          2
# 3 2020-02-02  Kerala      0       0          3
# 4 2020-02-03  Kerala      0       0          3

# %%
data.isnull().any()
# Out:
# Date         False
# State        False
# Cured        False
# Deaths       False
# Confirmed    False
# dtype: bool

# %%
data[data['Confirmed']==data['Confirmed'].max()]
# Out:
#           Date        State  Cured  Deaths  Confirmed
# 850 2020-04-11  Maharashtra    188     110       1574

# %%
data.tail()
# Out:
#           Date          State  Cured  Deaths  Confirmed
# 858 2020-04-11      Telengana     43       9        504
# 859 2020-04-11        Tripura      0       0          2
# 860 2020-04-11    Uttarakhand      5       0         35
# 861 2020-04-11  Uttar Pradesh     32       4        433
# 862 2020-04-11    West Bengal     16       5        126

# %%
today=data[data['Date']=='2020-04-11']
today
# Out:
#           Date                        State  Cured  Deaths  Confirmed
# 832 2020-04-11               Andhra Pradesh     11       6        381
# 833 2020-04-11  Andaman and Nicobar Islands      0       0         11
# 834 2020-04-11            Arunachal Pradesh      0       0          1
# 835 2020-04-11                        Assam      0       1         29
# 836 2020-04-11                        Bihar      0       1         60
# 837 2020-04-11                   Chandigarh      7       0         18
# 838 2020-04-11                 Chhattisgarh      9       0         18
# 839 2020-04-11                        Delhi     25      14        903
# 840 2020-04-11                          Goa      1       0          7
# 841 2020-04-11                      Gujarat     31      19        308
# 842 2020-04-11                      Haryana     29       3        177
# 843 2020-04-11             Himachal Pradesh      6       1         28
# ...

# %%
max_confirmed_cases=today.sort_values(by='Confirmed', ascending=False)

# %%
max_confirmed_cases
# Out:
#           Date                        State  Cured  Deaths  Confirmed
# 850 2020-04-11                  Maharashtra    188     110       1574
# 857 2020-04-11                   Tamil Nadu     44       8        911
# 839 2020-04-11                        Delhi     25      14        903
# 856 2020-04-11                    Rajasthan     21       3        553
# 858 2020-04-11                    Telengana     43       9        504
# 849 2020-04-11               Madhya Pradesh      0      33        443
# 861 2020-04-11                Uttar Pradesh     32       4        433
# 832 2020-04-11               Andhra Pradesh     11       6        381
# 847 2020-04-11                       Kerala    123       2        364
# 841 2020-04-11                      Gujarat     31      19        308
# 846 2020-04-11                    Karnataka     37       6        214
# 844 2020-04-11            Jammu and Kashmir      6       4        207
# ...

# %%
top_confirmed_cases=max_confirmed_cases[0:5]
top_confirmed_cases
# Out:
#           Date        State  Cured  Deaths  Confirmed
# 850 2020-04-11  Maharashtra    188     110       1574
# 857 2020-04-11   Tamil Nadu     44       8        911
# 839 2020-04-11        Delhi     25      14        903
# 856 2020-04-11    Rajasthan     21       3        553
# 858 2020-04-11    Telengana     43       9        504

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#sns.set(rc={'figure.figsize':(15,10)})
plt.figure(figsize=(15,10))
sns.barplot(x='State',y='Confirmed',data=top_confirmed_cases)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Confirmed'>

# %%
total_death_cases=today.sort_values(by='Deaths', ascending=False)
total_death_cases
# Out:
#           Date                        State  Cured  Deaths  Confirmed
# 850 2020-04-11                  Maharashtra    188     110       1574
# 849 2020-04-11               Madhya Pradesh      0      33        443
# 841 2020-04-11                      Gujarat     31      19        308
# 839 2020-04-11                        Delhi     25      14        903
# 855 2020-04-11                       Punjab      5      11        132
# 858 2020-04-11                    Telengana     43       9        504
# 857 2020-04-11                   Tamil Nadu     44       8        911
# 832 2020-04-11               Andhra Pradesh     11       6        381
# 846 2020-04-11                    Karnataka     37       6        214
# 862 2020-04-11                  West Bengal     16       5        126
# 844 2020-04-11            Jammu and Kashmir      6       4        207
# 861 2020-04-11                Uttar Pradesh     32       4        433
# ...

# %%
top_death_cases=total_death_cases[0:5]
top_death_cases
# Out:
#           Date           State  Cured  Deaths  Confirmed
# 850 2020-04-11     Maharashtra    188     110       1574
# 849 2020-04-11  Madhya Pradesh      0      33        443
# 841 2020-04-11         Gujarat     31      19        308
# 839 2020-04-11           Delhi     25      14        903
# 855 2020-04-11          Punjab      5      11        132

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x='State', y='Deaths', data=top_death_cases)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Deaths'>

# %%
total_cured_cases=data.sort_values(by=['Cured'], ascending=False)
total_cured_cases
# Out:
#           Date             State  Cured  Deaths  Confirmed
# 850 2020-04-11       Maharashtra    188     110       1574
# 819 2020-04-10       Maharashtra    125      97       1364
# 847 2020-04-11            Kerala    123       2        364
# 788 2020-04-09       Maharashtra    117      72       1135
# 816 2020-04-10            Kerala     96       2        357
# ..         ...               ...    ...     ...        ...
# 401 2020-03-27  Himachal Pradesh      0       1          3
# 406 2020-03-27    Madhya Pradesh      0       1         20
# 110 2020-03-12           Haryana      0       0         14
# 408 2020-03-27           Manipur      0       0          1
# 0   2020-01-30            Kerala      0       0          1
#
# [863 rows x 5 columns]

# %%
top_cured_cases=total_cured_cases[0:5]
top_cured_cases
# Out:
#           Date        State  Cured  Deaths  Confirmed
# 850 2020-04-11  Maharashtra    188     110       1574
# 819 2020-04-10  Maharashtra    125      97       1364
# 847 2020-04-11       Kerala    123       2        364
# 788 2020-04-09  Maharashtra    117      72       1135
# 816 2020-04-10       Kerala     96       2        357

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x='State',y='Cured', data=top_cured_cases, hue='State')
# Out:
# <AxesSubplot:xlabel='State', ylabel='Cured'>

# %%
#picking maharashtra and visualizing
maha=data[data['State']=='Maharashtra']
maha
# Out:
#           Date        State  Cured  Deaths  Confirmed
# 76  2020-03-09  Maharashtra      0       0          2
# 91  2020-03-10  Maharashtra      0       0          5
# 97  2020-03-11  Maharashtra      0       0          2
# 120 2020-03-12  Maharashtra      0       0         11
# 133 2020-03-13  Maharashtra      0       0         14
# 146 2020-03-14  Maharashtra      0       0         14
# 153 2020-03-15  Maharashtra      0       0         32
# 167 2020-03-16  Maharashtra      0       0         32
# 182 2020-03-17  Maharashtra      0       1         39
# 197 2020-03-18  Maharashtra      0       1         42
# 215 2020-03-19  Maharashtra      0       1         47
# 235 2020-03-20  Maharashtra      0       1         52
# 257 2020-03-21  Maharashtra      0       1         63
# 280 2020-03-22  Maharashtra      0       2         67
# 303 2020-03-23  Maharashtra      0       2         74
# 326 2020-03-24  Maharashtra      0       2         89
# ...

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='Date',y='Confirmed',data=maha, color='g')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Confirmed'>

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='Date',y='Deaths',data=maha,color='r')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Deaths'>

# %%
#visualizing data of Kerela
keral=data[data['State']=='Kerala']
keral
# Out:
#           Date   State  Cured  Deaths  Confirmed
# 0   2020-01-30  Kerala      0       0          1
# 1   2020-01-31  Kerala      0       0          1
# 2   2020-02-01  Kerala      0       0          2
# 3   2020-02-02  Kerala      0       0          3
# 4   2020-02-03  Kerala      0       0          3
# ..         ...     ...    ...     ...        ...
# 723 2020-04-07  Kerala     58       2        327
# 754 2020-04-08  Kerala     70       2        336
# 785 2020-04-09  Kerala     83       2        345
# 816 2020-04-10  Kerala     96       2        357
# 847 2020-04-11  Kerala    123       2        364
#
# [73 rows x 5 columns]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='Date', y='Confirmed', data=keral, color='g')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Confirmed'>

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='Date', y='Deaths', data=keral, color='r')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Deaths'>

# %%
#visualizing Delhi records
delhi=data[data['State']=='Delhi']
delhi
# Out:
#           Date  State  Cured  Deaths  Confirmed
# 34  2020-03-02  Delhi      0       0          1
# 38  2020-03-03  Delhi      0       0          1
# 42  2020-03-04  Delhi      0       0          1
# 45  2020-03-05  Delhi      0       0          2
# 51  2020-03-06  Delhi      0       0          3
# 62  2020-03-07  Delhi      0       0          3
# 71  2020-03-08  Delhi      0       0          3
# 84  2020-03-09  Delhi      0       0          4
# 87  2020-03-10  Delhi      0       0          4
# 98  2020-03-11  Delhi      0       0          5
# 109 2020-03-12  Delhi      0       0          6
# 122 2020-03-13  Delhi      0       0          6
# 135 2020-03-14  Delhi      1       1          7
# 149 2020-03-15  Delhi      2       1          7
# 163 2020-03-16  Delhi      2       1          7
# 178 2020-03-17  Delhi      2       1          8
# 193 2020-03-18  Delhi      2       1         10
# 211 2020-03-19  Delhi      3       1         12
# 230 2020-03-20  Delhi      5       1         17
# ...

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='Date', y='Confirmed', data=delhi, color='g')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Confirmed'>

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='Date', y='Deaths', data=delhi, color='r')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Deaths'>

# %%
from sklearn.model_selection import train_test_split

# %%
maha['Date']=maha['Date'].map(dt.datetime.toordinal)
maha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 76 to 850
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       34 non-null     int64
#  1   State      34 non-null     object
#  2   Cured      34 non-null     int64
#  3   Deaths     34 non-null     int64
#  4   Confirmed  34 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.6+ KB
# <ipython-input-30-b8fac5d42005>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maha['Date']=maha['Date'].map(dt.datetime.toordinal)

# %%
maha.head()
# Out:
#        Date        State  Cured  Deaths  Confirmed
# 76   737493  Maharashtra      0       0          2
# 91   737494  Maharashtra      0       0          5
# 97   737495  Maharashtra      0       0          2
# 120  737496  Maharashtra      0       0         11
# 133  737497  Maharashtra      0       0         14

# %%
x=maha['Date']
y=maha['Confirmed']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()

# %%
x_train
# Out:
# 407    737511
# 696    737521
# 726    737522
# 788    737524
# 461    737513
# 350    737509
# 146    737498
# 215    737503
# 197    737502
# 257    737505
# 133    737497
# 516    737515
# 153    737499
# 546    737516
# 167    737500
# 280    737506
# 182    737501
# 235    737504
# 819    737525
# 488    737514
# 757    737523
# 91     737494
# 605    737518
# Name: Date, dtype: int64

# %%
y
# Out:
# 76        2
# 91        5
# 97        2
# 120      11
# 133      14
# 146      14
# 153      32
# 167      32
# 182      39
# 197      42
# 215      47
# 235      52
# 257      63
# 280      67
# 303      74
# 326      89
# 350     128
# 380     124
# 407     130
# 434     180
# 461     186
# 488     198
# 516     216
# 546     302
# 575     335
# 605     335
# 636     490
# 666     490
# 696     748
# 726     868
# 757    1018
# 788    1135
# 819    1364
# 850    1574
# Name: Confirmed, dtype: int64

# %%
print(x.shape)
print(y.shape)
print(x_train.shape)
print(y_train.shape)
y_train
# Out:
# (34,)
# (34,)
# (23,)
# (23,)
# 407     130
# 696     748
# 726     868
# 788    1135
# 461     186
# 350     128
# 146      14
# 215      47
# 197      42
# 257      63
# 133      14
# 516     216
# 153      32
# 546     302
# 167      32
# 280      67
# 182      39
# 235      52
# 819    1364
# 488     198
# 757    1018
# 91        5
# 605     335
# Name: Confirmed, dtype: int64

# %%
#we have to remove index
import numpy as np
model.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# <ipython-input-38-f3adf3c92ca9>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# RandomForestRegressor()

# %%
predicted=model.predict(np.array(x_test).reshape(-1,1))

# %%
predicted
# Out:
# array([ 660.56,   12.29,  106.83,  444.75,    8.96,    8.96,  295.64,
#         130.61,   71.74,  150.14, 1270.72])

# %%
maha.tail()
# Out:
#        Date        State  Cured  Deaths  Confirmed
# 726  737522  Maharashtra     56      48        868
# 757  737523  Maharashtra     79      64       1018
# 788  737524  Maharashtra    117      72       1135
# 819  737525  Maharashtra    125      97       1364
# 850  737526  Maharashtra    188     110       1574

# %%
model.predict(np.array([[737625]]))
# Out:
# array([1270.72])
